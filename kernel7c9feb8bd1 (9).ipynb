# %% [markdown]
# # Introduction

# %% [markdown]
# Acknowledgements
#
# The data was scraped from WineEnthusiast during the week of June 15th, 2017. The code for the scraper can be found here if you have any more specific questions about data collection that I didn't address.
#
# UPDATE 11/24/2017 After feedback from users of the dataset I scraped the reviews again on November 22nd, 2017. This time around I collected the title of each review, which you can parse the year out of, the tasters name, and the taster's Twitter handle. This should also fix the duplicate entry issue.[](http://)

# %% [markdown]
# # Index
#
# 1. [Understand the dataset](#1.-Understand-the-dataset)
#     * [1.1 Basic data cleansing](#1.1-Basic-data-cleansing)
#     * [1.2 Feature study](#1.2-Feature-study)
#         * [Country](#Country)
#         * [Variety(Types of grapes)](#Variety(Types-of-grapes))
#         * [Points](#Country)
#         * [Price](#Price)
#
#
# 2. [Questions to answer](#2.-Questions-to-answer)
#     * [2.1 Does a costly wine means good points?](#2.1-Does-a-costly-wine-means-good-points?)
#     * [2.2 Which countries/regions are more likely to produce good wines?](#2.2-Which-countries/regions-are-more-likely-to-produce-good-wines?)
#     * [2.3 Can we deduce good points or price from the type of grapes?](#2.3-Can-we-deduce-good-points-or-price-from-the-type-of-grapes?)
#     * [2.4 Are there any characteristics to describe wine of a country and type of grapes?](#2.4-Are-there-any-characteristics-to-describe-wine-of-a-country-and-type-of-grapes?)

# %%
'''{
    "tags": [
        "hide_input",
    ]
}'''
# Out:
# '{\n    "tags": [\n        "hide_input",\n    ]\n}'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.stats import ttest_ind

from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer 
#from nltk.stem import LancasterStemmer, WordNetLemmatizer

from wordcloud import WordCloud

from sklearn.feature_extraction import text
from sklearn.metrics import classification_report

import random

# %%
df = pd.read_csv('../input/winemag-data_first150k.csv')

# %%
'''df = pd.read_csv(r'C:/eval/wine_review/winemag-data_first150k.csv')
'''
# Out:
# "df = pd.read_csv(r'C:/eval/wine_review/winemag-data_first150k.csv')\n"

# %% [markdown]
# ## 1. Understand the dataset

# %% [markdown]
# Snapshot of the dataset:

# %%
df.head()
# Out:
#    Unnamed: 0           ...                              winery
# 0           0           ...                               Heitz
# 1           1           ...             Bodega Carmen Rodríguez
# 2           2           ...                            Macauley
# 3           3           ...                               Ponzi
# 4           4           ...                Domaine de la Bégude
#
# [5 rows x 11 columns]

# %% [markdown]
# Number of entries of each variables and data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
# Unnamed: 0     150930 non-null int64
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %% [markdown]
# Terminology:
#
#
# Points: the number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post reviews for wines that score >=80)<br>
# Title: the title of the wine review, which often contains the vintage if you're interested in extracting that feature<br>
# Variety: the type of grapes used to make the wine (ie Pinot Noir)<br>
# Description: a few sentences from a sommelier describing the wine's taste, smell, look, feel, etc.<br>
# Country: the country that the wine is from<br>
# Province: the province or state that the wine is from<br>
# Region 1: the wine growing area in a province or state (ie Napa)<br>
# Region 2: sometimes there are more specific regions specified within a wine growing area (ie Rutherford inside the Napa Valley), but this value can sometimes be blank<br>
# Winery: the winery that made the wine<br>
# Designation: the vineyard within the winery where the grapes that made the wine are from<br>
# Price: the cost for a bottle of the wine<br>
# Taster Name: name of the person who tasted and reviewed the wine<br>
# Taster Twitter Handle: Twitter handle for the person who tasted ane reviewed the wine<br>

# %% [markdown]
# Basic information about continuous variables of the dataset:

# %%
df.describe()
# Out:
#           Unnamed: 0         points          price
# count  150930.000000  150930.000000  137235.000000
# mean    75464.500000      87.888418      33.131482
# std     43569.882402       3.222392      36.322536
# min         0.000000      80.000000       4.000000
# 25%     37732.250000      86.000000      16.000000
# 50%     75464.500000      88.000000      24.000000
# 75%    113196.750000      90.000000      40.000000
# max    150929.000000     100.000000    2300.000000

# %% [markdown]
# ## 1.1 Basic data cleansing

# %% [markdown]
# Cleansing work on
# 1.  removing column 'Unnamed: 0' <br>
# 2.  remove duplicated rows

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
# Remove duplicated rows
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97851 entries, 0 to 149639
# Data columns (total 10 columns):
# country        97848 non-null object
# description    97851 non-null object
# designation    67955 non-null object
# points         97851 non-null int64
# price          89131 non-null float64
# province       97848 non-null object
# region_1       81919 non-null object
# region_2       39491 non-null object
# variety        97851 non-null object
# winery         97851 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 8.2+ MB

# %% [markdown]
# Remarks: Parameters without missing entries: description, points, variety, winery

# %% [markdown]
# ## 1.2 Feature study

# %% [markdown]
# ### Country

# %%
df_country = df['country'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['country','counts']

# %%
fig, ax = plt.subplots(figsize=(15,10));
sns.barplot(data = df_country, x='country',y='counts',ax=ax).set_title('Number of samples under each country');
plt.xticks(rotation='vertical');

# %% [markdown]
# In the dataset around 40% of them were from US, and the sequence of wine producing volumn is different from information indicated in below link:<br>
#
# https://aroundtheworldin80harvests.com/2018/07/30/wine-production-by-country/
#
# Country  –  Production in 2017(million hectolitres)<br>
# Italy – 39.3 <br>
# France – 36.7 <br>
# Spain – 33.5 <br>
# The United States – 23.3 <br>
# Australia – 13.9 <br>
# Argentina – 11.8 <br>
# China – 11.4 <br>
# South Africa – 10.8 <br>
# Chile – 9.5 <br>
# Germany – 8.1 <br>
# World Total – 246.7
#
#
# This implies possible bias in studying the dataset if there is any features favoring wines from US. To test this I'd set up a hypothesis test on price and points for dataset of US against all other countries.

# %%
#form one dataframe only includes US and another excludes US for coparison
df_us = df[df['country']=='US']
df_us.dropna(subset=['price', 'points'],inplace=True)
US_index = df_us.index
df_us = df[df['country']=='US']
US_index = df_us.index
df_nonus = df.drop(US_index)

df_us.dropna(subset=['price', 'points'],inplace=True)
df_nonus.dropna(subset=['price', 'points'],inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# Hypothsis test on points:

# %%
ttest_ind(df_us['points'], df_nonus['points'],equal_var=False)
# Out:
# Ttest_indResult(statistic=3.171325662692179, pvalue=0.0015180053730552273)

# %% [markdown]
# Hypothsis test on price:

# %%
ttest_ind(df_us['price'], df_nonus['price'],equal_var=False)
# Out:
# Ttest_indResult(statistic=3.4793602705329802, pvalue=0.0005028789461803278)

# %% [markdown]
# Since both p-values are quite low so we cannot say there is no significant difference within two dataset.<br>
# One way to reduce the factor of bias in sampling from particular country is to draw samples from countries with ratio following world production but it does not seem to be feasible from the dataset due to limitation of sample size of certain countries with high production volume(e.g. China)

# %% [markdown]
# ### Variety(Type of grape)

# %%
print('According to the dataset, there are {0} types of grapes'.format(df['variety'].nunique()))
# Out:
# According to the dataset, there are 632 types of grapes

# %% [markdown]
# Let's take a close look on top 10 types of grapes in the data set.

# %%
df_variety = df['variety'].value_counts().to_frame()
df_variety.reset_index(inplace=True)
df_variety.columns=['variety', 'counts']
df_variety_trimmed = df_variety.loc[0:9]

# %%
fig, ax = plt.subplots(figsize=(15,10));
sns.barplot(data = df_variety_trimmed, x='variety',y='counts',ax=ax).set_title('Number of observations under top 10 types of grapes');
plt.xticks(rotation='vertical');

# %% [markdown]
# It seems Pinot Noir is the most abundent type of grapes but also take a look below integrating countries(top 10 sample quantity):

# %%
#make top 10 types of grapes into list
grape_list=list(df_variety_trimmed['variety'])

# %%
#make list of top 10 countries(wine production)

country_trimmed = df_country.loc[0:9]
country_list=list(country_trimmed['country'])

# %%
#generate heatmap
df_top_variety_country= df[df['variety'].isin(grape_list)]
df_top_variety_country = df_top_variety_country[df_top_variety_country['country'].isin(country_list)]
df_top_variety_country = df_top_variety_country.groupby(['country','variety']).size().unstack(level=-1)
df_top_variety_country.replace(np.nan,0,inplace=True)

fig, ax = plt.subplots(figsize=(10,10));
sns.heatmap(df_top_variety_country,cmap = 'Reds',annot=True, annot_kws={"size": 8},ax=ax).set_title('Production of types of grape on countries');

# %% [markdown]
# Above heatmap shows the dataset is biased to wine produced in US which produces lots of Pinot Noir

# %% [markdown]
# ------------------------------------------------------------------

# %% [markdown]
# ## Points

# %%
sns.countplot(df['points']).set_title('Distribution of points');

# %%
print("It may be interesting to know what wines score the highest points. There are totally {} wines scoring 100 points.".format(df[df['points']==100]['points'].count()))
print("Details are shown below:")
# Out:
# It may be interesting to know what wines score the highest points. There are totally 11 wines scoring 100 points.
# Details are shown below:

# %%
df[df['points']==100].sort_values(['country','designation'])
# Out:
#           country             ...                                    winery
# 19355   Australia             ...               Chambers Rosewood Vineyards
# 26296      France             ...                                      Krug
# 2145       France             ...                        Château Haut-Brion
# 28954       Italy             ...                        Giovanni Chiappini
# 24151       Italy             ...                     Tenuta dell'Ornellaia
# 111087      Italy             ...                                Avignonesi
# 19354          US             ...                                    Cayuse
# 92916          US             ...                                    Shafer
# 98647          US             ...                           Williams Selyem
# 114272         US             ...                                     Sloan
# 89399          US             ...                                 Cardinale
#
# [11 rows x 10 columns]

# %%
df_price_notna=df[df['price'].notna()]

# %% [markdown]
# ## Price

# %%
fig, ax = plt.subplots(figsize=(15,8));
sns.distplot(df_price_notna['price'],bins=500,ax=ax);
plt.xticks(np.arange(0, 2400, step=50),rotation='vertical');

# %%
df['price'].describe()
# Out:
# count    89131.000000
# mean        33.658783
# std         37.670180
# min          4.000000
# 25%         16.000000
# 50%         25.000000
# 75%         40.000000
# max       2300.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Winery

# %%
df_winery = df['winery'].value_counts().to_frame()
df_winery.reset_index(inplace=True)
df_winery.columns=['winery', 'counts']
#df_winery_trimmed = df_variety.loc[0:9]
df_winery
# Out:
#                                       winery  counts
# 0                            Williams Selyem     235
# 1                                 Testarossa     171
# 2                      Chateau Ste. Michelle     156
# 3                             Columbia Crest     152
# 4                                 DFJ Vinhos     148
# 5                              Concha y Toro     132
# 6                            Georges Duboeuf     129
# 7                            Kendall-Jackson     125
# 8                             Joseph Drouhin     121
# 9                                   Trapiche     120
# 10                              Louis Latour     118
# 11                            Robert Mondavi     116
# 12                                   Kenwood     115
# 13                        Wines & Winemakers     113
# 14                                  De Loach     112
# 15                      Bouchard Père & Fils     108
# 16                                     Hogue     102
# 17                              Gary Farrell     102
# 18                            Cameron Hughes     101
# 19                             Albert Bichot     100
# 20                        Dry Creek Vineyard      98
# 21                                Martin Ray      97
# 22                                D'Arenberg      97
# 23                                 Santa Ema      96
# 24                                 Errazuriz      95
# 25                                   Yalumba      94
# 26                          Olivier Leflaive      93
# 27                                    Morgan      92
# 28                            L'Ecole No. 41      91
# 29                                    Montes      91
# ...                                      ...     ...
# 14780                       Domaine du Touja       1
# 14781                   Château Roc de Ségur       1
# 14782                           Viña Paquita       1
# 14783                              Vivo Vino       1
# 14784                                    SIP       1
# 14785                      Château de Rhodes       1
# 14786                            Dr. Volkmar       1
# 14787                        Badger Mountain       1
# 14788                  Château Fourcas-Borie       1
# 14789  Union de Vignerons de l'Île de Beauté       1
# 14790                       Château Peugeais       1
# 14791                    Château l'Espérance       1
# 14792                         Château Maurac       1
# 14793                       Essencia Vendima       1
# 14794                                Arbiola       1
# 14795                      Château la Hargue       1
# 14796                    Terrazze Della Luna       1
# 14797                  Château les Tonnelles       1
# 14798                Château la Tour de Mons       1
# 14799                       Château Lamarque       1
# 14800                      Altos del Marqués       1
# 14801                         Viña del Sopié       1
# 14802                 Cosecheros y Criadores       1
# 14803                              Résonance       1
# 14804                              Bel Arbor       1
# 14805                 G.A. Rossi di Medelana       1
# 14806                  Bodega Antigua Usanza       1
# 14807                        Cantine Galasso       1
# 14808                          Von Der Leyen       1
# 14809                             Redemption       1
#
# [14810 rows x 2 columns]

# %% [markdown]
# ------------------------------------------------------------------

# %% [markdown]
# ## 2. Questions to answer

# %% [markdown]
# After studied basic features, here it pops out some questions in my mind,
# 1. Does a costly wine means good points?
# 2. Which country/regions are more likely to produce good wines?
# 3. Can we deduce good points or price from the type of grapes?
# 4. Any characteristics to describe wine of a country
# 4.

# %% [markdown]
# ### 2.1 Does a costly wine means good points?

# %% [markdown]
# I tried to put price and points together to see if there is a clear relationship:

# %%
fig, ax = plt.subplots(figsize=(10,8));
sns.boxplot(data=df,x='points',y='price');
plt.yticks(np.arange(0, 2500, step=100));
plt.grid();

# %%
df.corr()
# Out:
#           points     price
# points  1.000000  0.447355
# price   0.447355  1.000000

# %% [markdown]
# Although fairly good wine can be sold at low cost, we do not see wines scoring very high are sold at cheap prices.
#
# Want some affordable and good quality wine? Here is picked list for reference:

# %%
df_cheapNgood = df[(df['price']<=50) & 
                   (df['points']>=96)].sort_values(['country','points','price'])
df_cheapNgood
# Out:
#           country             ...                                    winery
# 83001   Argentina             ...                                    Riglos
# 17162      France             ...                      Domaine Marcel Deiss
# 2459       France             ...               Château Malartic-Lagravière
# 127498    Germany             ...                                Dr. Loosen
# 10541       Italy             ...                             Isole e Olena
# 2449        Italy             ...                                   Baricci
# 37932       Italy             ...                            Poggio Nardone
# 10601       Spain             ...                             La Rioja Alta
# 56971          US             ...                                      Rulo
# 65333          US             ...                               Fess Parker
# 81970          US             ...                                    Efeste
# 56974          US             ...                                    Rusack
# 89648          US             ...                               Boekenoogen
# 16105          US             ...                              Robert Young
# 87437          US             ...                             Au Bon Climat
# 56973          US             ...                                      Ojai
# 21423          US             ...                            Marimar Estate
# 2439           US             ...                                     Stolo
# 26667          US             ...                                Scott Paul
# 89646          US             ...                                 Bjornstad
# 89647          US             ...                                 Bjornstad
# 98658          US             ...                           Williams Selyem
# 127610         US             ...                              Gary Farrell
# 26309          US             ...                         Long Meadow Ranch
# 22066          US             ...                           Woodward Canyon
# 22067          US             ...                                   Samsara
# 135145         US             ...                                    Talley
# 18619          US             ...                                  De Loach
# 24167          US             ...                          Dutton-Goldfield
# 61053          US             ...                            Hartford Court
# 75827          US             ...                                  Gramercy
# 81967          US             ...                               Stonestreet
# 84773          US             ...                                    Dunham
# 108688         US             ...                            Marimar Estate
# 115159         US             ...                          Chateau St. Jean
# 120709         US             ...                                  Longoria
# 148048         US             ...                                  De Loach
# 34201          US             ...                           Roederer Estate
# 81969          US             ...                                      Buty
# 89649          US             ...                                      Buty
# 98654          US             ...                                 Chronicle
# 42807          US             ...                           Williams Selyem
# 56975          US             ...                           Williams Selyem
# 64627          US             ...                                 Bjornstad
# 69023          US             ...                           Terra Valentine
# 92924          US             ...                                    Siduri
# 104203         US             ...                          Tamarack Cellars
# 107551         US             ...                              Gary Farrell
# 116558         US             ...                                  Roessler
# 127771         US             ...                                    Hestan
# 144495         US             ...                              Robert Young
# 70231          US             ...                                    Failla
# 42803          US             ...                           Williams Selyem
# 55504          US             ...                                   Sequana
# 104200         US             ...                          Dutton-Goldfield
# 127493         US             ...                                 Trefethen
# 34924          US             ...                                 Pirouette
#
# [57 rows x 10 columns]

# %% [markdown]
# ## 2.2 Which countries/regions are more likely to produce good wines?

# %%
fig, ax = plt.subplots(figsize=(18,8));
sns.boxplot(data = df,x = 'country', y='points',ax=ax,order=df_country['country']).set_title('Distribution of Points by Countries');
plt.xticks(rotation='vertical');
plt.yticks(np.arange(80, 102, step=2));

# %%
best_regions=df.groupby(['region_1']).median().sort_values(by='points',ascending=False)
best_regions.reset_index(inplace=True)

# %%
hm_best_regions=df[df['region_1'].isin(list(best_regions['region_1'].iloc[0:19]))]
hm_best_regions = hm_best_regions.groupby(['region_1','points']).size().unstack()

fig, ax = plt.subplots(figsize=(18,12));
sns.heatmap(hm_best_regions,cmap = 'YlGnBu',annot=True, annot_kws={"size": 8},ax=ax);

# %%
df_good_region_1=df.groupby('region_1').size().to_frame().reset_index()
df_good_region_1.columns=['region_1','count']

# %%
df_good_region_1=pd.merge(df_good_region_1,best_regions,on='region_1')
df_good_region_1=df_good_region_1[(df_good_region_1['count']>50) & (df_good_region_1['points']>90)].sort_values(['points','price'],ascending=False)

# %%
df_temp=df[df['region_1'].isin(list(df_good_region_1['region_1'].iloc[0:18]))]
fig, ax = plt.subplots(figsize=(18,8));
sns.boxplot(data = df_temp,x = 'region_1', y='points',
            order = list(df_good_region_1['region_1'].iloc[0:18]),ax=ax).set_title('Distribution of Points by Regions');

plt.xticks(rotation='vertical');
plt.yticks(np.arange(80, 102, step=2));

# %%
df_temp=df[df['region_1'].isin(list(df_good_region_1['region_1'].iloc[0:18]))]
fig, ax = plt.subplots(figsize=(18,8));
sns.boxplot(data = df_temp,x = 'region_1', y='price',order = list(df_good_region_1['region_1'].iloc[0:18]),ax=ax).set_title('Distribution of Price by Regions');

plt.xticks(rotation='vertical');

# %%
sns.lmplot(data=df_temp,x='points',y='price',hue='region_1',col='region_1',
           col_order=list(df_good_region_1['region_1'].iloc[0:18]),col_wrap =3,
           hue_order=list(df_good_region_1['region_1'].iloc[0:18]),
           scatter_kws={'alpha':0.8,"s": 10},x_jitter=.1,fit_reg=False,sharey=False);

# %% [markdown]
# *lots of wine produced in Barsac does not mention price

# %% [markdown]
# You may see that wines from France has narrower density band than other countries, which means price distribution of wine is the widest.

# %%
#fig, ax = plt.subplots(figsize=(18,8));
sns.lmplot(data=df_top_country,
           x='points',y='price',hue='country',scatter_kws={'alpha':0.7},
           x_jitter=.2,size=8,palette='muted',fit_reg=False);
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 2.3 Can we deduce good points or price from the type of grapes?

# %%
df_variety = df['variety'].value_counts().to_frame().sort_values(by='variety',ascending=False)
df_variety.reset_index(inplace=True)
df_variety.columns=['variety', 'counts']
df_variety_trimmed = df_variety.loc[0:9]

grape_list=list(df_variety_trimmed['variety'])

# %%
df_trimmed=df[df['variety'].isin(grape_list)]

# %%
grape_list_median = list(df_trimmed.groupby('variety').median().
     sort_values(by='points',ascending=False).reset_index()['variety'])

# %%
fig, ax = plt.subplots(figsize=(15,10));
sns.boxplot(data = df_trimmed, x='variety', y='points', order = grape_list_median, ax=ax).set_title(
    'Distribution of points by type of grapes')
plt.xticks(rotation='vertical');

# %%
sns.lmplot(data=df_trimmed,x='points',y='price',hue='variety',
           col='variety',col_wrap =3,col_order = grape_list_median ,
           hue_order = grape_list_median ,scatter_kws={'alpha':0.5},
           y_jitter=.2,fit_reg=False,sharey=False);

# %% [markdown]
# ## 2.4 Are there any characteristics to describe wine of a country and type of grapes

# %%
#form dataframe
df_word = df[['description','country','variety']]
df_word = df_word[df_word['variety'].notna()]
df_word = df_word[df_word['variety'].isin(grape_list)]
df_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55251 entries, 0 to 149639
# Data columns (total 3 columns):
# description    55251 non-null object
# country        55249 non-null object
# variety        55251 non-null object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
#change to lower case
df_word['description'] = df_word['description'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_word['description'].head()
# Out:
# 0    this tremendous 100% varietal wine hails from ...
# 2    mac watson honors the memory of a wine once ma...
# 3    this spent 20 months in 30% new french oak, an...
# 8    this re-named vineyard was formerly bottled as...
# 9    the producer sources from two blocks of the vi...
# Name: description, dtype: object

# %%
#remove punctuation
df_word['description'] = df_word['description'].str.replace('[^\w\s]','')
df_word['description'].head()
# Out:
# 0    this tremendous 100 varietal wine hails from o...
# 2    mac watson honors the memory of a wine once ma...
# 3    this spent 20 months in 30 new french oak and ...
# 8    this renamed vineyard was formerly bottled as ...
# 9    the producer sources from two blocks of the vi...
# Name: description, dtype: object

# %%
#remove stopwords
stopword = stopwords.words('english')
df_word['description'] = df_word['description'].apply(lambda x: " ".join(x for x in x.split() if x not in stopword))
df_word['description'].head()
# Out:
# 0    tremendous 100 varietal wine hails oakville ag...
# 2    mac watson honors memory wine made mother trem...
# 3    spent 20 months 30 new french oak incorporates...
# 8    renamed vineyard formerly bottled delancellott...
# 9    producer sources two blocks vineyard wineone h...
# Name: description, dtype: object

# %%
#remove most frequent words
freq = ' '.join(df_word['description'])
freq=pd.Series(freq.split())
freq.value_counts()[:20]
# Out:
# flavors    30659
# wine       30560
# fruit      20388
# tannins    13694
# finish     13416
# cherry     12011
# acidity    11794
# ripe       10739
# black       9952
# aromas      9935
# dry         9673
# palate      9441
# oak         9144
# drink       9141
# rich        8433
# sweet       7625
# red         6976
# spice       6854
# notes       6808
# soft        6646
# dtype: int64

# %% [markdown]
# I decide to trim away top 5 words since they do not indicate too much about wine characteristics

# %%
#Form list of top 3 words
most_freq_words=freq.value_counts()[:2]

#Remove words in top 5 words
df_word['description'] = df_word['description'].apply(lambda x: " ".join(x for x in x.split() if x not in most_freq_words))
df_word['description'].head()
# Out:
# 0    tremendous 100 varietal hails oakville aged th...
# 2    mac watson honors memory made mother tremendou...
# 3    spent 20 months 30 new french oak incorporates...
# 8    renamed vineyard formerly bottled delancellott...
# 9    producer sources two blocks vineyard wineone h...
# Name: description, dtype: object

# %% [markdown]
# Below I will use WordCloud to show the most common words(bigger words means appear more frequently)

# %%
wordcloud = WordCloud(background_color='white',max_words=200,max_font_size=150, width=1200, height=1000).generate(" ".join(df_word['description'].astype(str)))

fig = plt.figure(figsize = (12,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show();

# %%
#Stemmerization
stemmer = PorterStemmer()
df_word['description'] = df_word['description'].apply(lambda x: " ".join(stemmer.stem(word) for word in x.split()))
df_word['description'].head()
# Out:
# 0    tremend 100 variet hail oakvil age three year ...
# 2    mac watson honor memori made mother tremend de...
# 3    spent 20 month 30 new french oak incorpor frui...
# 8    renam vineyard formerli bottl delancellotti yo...
# 9    produc sourc two block vineyard wineon high el...
# Name: description, dtype: object

# %%
#Change to BOW
tfidf=text.TfidfVectorizer(stop_words=stopwords.words('english'))
matrix=tfidf.fit_transform(df_word['description'])

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(matrix, df_word['variety'], test_size=0.2, random_state=0)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train,y_train)
MultinomialNB()
clf.predict(X_test)
# Out:
# array(['Cabernet Sauvignon', 'Bordeaux-style Red Blend',
#        'Cabernet Sauvignon', ..., 'Cabernet Sauvignon',
#        'Bordeaux-style Red Blend', 'Pinot Noir'], dtype='<U24')

# %%
print (classification_report(y_test, clf.predict(X_test)));
# Out:
#                           precision    recall  f1-score   support
#
# Bordeaux-style Red Blend       0.83      0.57      0.68      1013
#       Cabernet Sauvignon       0.48      0.86      0.62      1683
#               Chardonnay       0.65      0.97      0.78      1897
#                   Merlot       0.00      0.00      0.00       599
#               Pinot Noir       0.63      0.89      0.74      1905
#                Red Blend       0.67      0.66      0.66      1218
#                 Riesling       0.99      0.35      0.51       726
#          Sauvignon Blanc       0.99      0.35      0.52       774
#                    Syrah       1.00      0.02      0.04       723
#                Zinfandel       1.00      0.08      0.15       513
#
#                 accuracy                           0.63     11051
#                macro avg       0.72      0.48      0.47     11051
#             weighted avg       0.69      0.63      0.57     11051
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### WORDVEC

# %%
from gensim.models import Word2Vec

# %%
#from gensim.utils import simple_preprocess

# %%
doc = df_word['description'].apply(lambda x:x.split())

w2v_model = Word2Vec(size=300, window=10, min_count=20, sg=1)
w2v_model.build_vocab(doc)

w2v_model.train(sentences=doc, total_examples=len(doc), epochs=w2v_model.iter)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# (5341361, 6503760)

# %%
word_vectors = w2v_model.wv
count = 0
for word in word_vectors.vocab:
    if count<10:
        print(word)
        count += 1
    else:
        break
# Out:
# tremend
# 100
# variet
# hail
# oakvil
# age
# three
# year
# oak
# juici

# %%
wanted_words = []
count = 0
for word in word_vectors.vocab:
    if count<300:
        wanted_words.append(word)
        count += 1
    else:
        break
wanted_vocab = dict((k, word_vectors.vocab[k]) for k in wanted_words if k in word_vectors.vocab)
wanted_vocab
# Out:
# {'tremend': <gensim.models.keyedvectors.Vocab at 0x7f04de63e0b8>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x7f04dba50390>,
#  'variet': <gensim.models.keyedvectors.Vocab at 0x7f04dba50358>,
#  'hail': <gensim.models.keyedvectors.Vocab at 0x7f04dba50438>,
#  'oakvil': <gensim.models.keyedvectors.Vocab at 0x7f04dba50470>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f04dba504a8>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f04dba504e0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f04dba50518>,
#  'oak': <gensim.models.keyedvectors.Vocab at 0x7f04dba50550>,
#  'juici': <gensim.models.keyedvectors.Vocab at 0x7f04dba50588>,
#  'redcherri': <gensim.models.keyedvectors.Vocab at 0x7f04dba505c0>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x7f04dba505f8>,
#  'compel': <gensim.models.keyedvectors.Vocab at 0x7f04dba50630>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f04dba50668>,
#  'caramel': <gensim.models.keyedvectors.Vocab at 0x7f04dba506a0>,
#  'greet': <gensim.models.keyedvectors.Vocab at 0x7f04dba506d8>,
#  'palat': <gensim.models.keyedvectors.Vocab at 0x7f04dba50710>,
#  'frame': <gensim.models.keyedvectors.Vocab at 0x7f04dba50748>,
#  'eleg': <gensim.models.keyedvectors.Vocab at 0x7f04dba50780>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7f04dba507b8>,
#  'tannin': <gensim.models.keyedvectors.Vocab at 0x7f04dba507f0>,
#  'subtl': <gensim.models.keyedvectors.Vocab at 0x7f04dba50828>,
#  'minti': <gensim.models.keyedvectors.Vocab at 0x7f04dba50860>,
#  'tone': <gensim.models.keyedvectors.Vocab at 0x7f04dba50898>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x7f04dba50048>,
#  'balanc': <gensim.models.keyedvectors.Vocab at 0x7f04dba50080>,
#  'reward': <gensim.models.keyedvectors.Vocab at 0x7f04dba500b8>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f04dba500f0>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7f04dba50128>,
#  'ahead': <gensim.models.keyedvectors.Vocab at 0x7f04dba50160>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7f04dba50198>,
#  'nuanc': <gensim.models.keyedvectors.Vocab at 0x7f04dba501d0>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7f04dba50208>,
#  'honor': <gensim.models.keyedvectors.Vocab at 0x7f04dba50240>,
#  'memori': <gensim.models.keyedvectors.Vocab at 0x7f04dba50278>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f04dba502b0>,
#  'delici': <gensim.models.keyedvectors.Vocab at 0x7f04dba502e8>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x7f04dba50320>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f04de3829e8>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f04de382a20>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x7f04de382a58>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7f04de382a90>,
#  'layer': <gensim.models.keyedvectors.Vocab at 0x7f04de382ac8>,
#  'toast': <gensim.models.keyedvectors.Vocab at 0x7f04de382b00>,
#  'hazelnut': <gensim.models.keyedvectors.Vocab at 0x7f04de382b38>,
#  'pear': <gensim.models.keyedvectors.Vocab at 0x7f04de382b70>,
#  'compot': <gensim.models.keyedvectors.Vocab at 0x7f04de382ba8>,
#  'orang': <gensim.models.keyedvectors.Vocab at 0x7f04de382be0>,
#  'peel': <gensim.models.keyedvectors.Vocab at 0x7f04de382c18>,
#  'revel': <gensim.models.keyedvectors.Vocab at 0x7f04de382c50>,
#  'succul': <gensim.models.keyedvectors.Vocab at 0x7f04de382c88>,
#  'gl': <gensim.models.keyedvectors.Vocab at 0x7f04de382cc0>,
#  'residu': <gensim.models.keyedvectors.Vocab at 0x7f04de382cf8>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x7f04de382d30>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f04de382d68>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7f04de382da0>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x7f04de382dd8>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x7f04de382e10>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f04de382e48>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x7f04de382e80>,
#  'incorpor': <gensim.models.keyedvectors.Vocab at 0x7f04de382eb8>,
#  'vineyard': <gensim.models.keyedvectors.Vocab at 0x7f04de382ef0>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f04de382f28>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f04de382f60>,
#  'aromat': <gensim.models.keyedvectors.Vocab at 0x7f04de382f98>,
#  'dens': <gensim.models.keyedvectors.Vocab at 0x7f04de382fd0>,
#  'toasti': <gensim.models.keyedvectors.Vocab at 0x7f04de382208>,
#  'deftli': <gensim.models.keyedvectors.Vocab at 0x7f04de382240>,
#  'blend': <gensim.models.keyedvectors.Vocab at 0x7f04de382278>,
#  'aroma': <gensim.models.keyedvectors.Vocab at 0x7f04de3822b0>,
#  'cigar': <gensim.models.keyedvectors.Vocab at 0x7f04de3822e8>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7f04de382320>,
#  'blackberri': <gensim.models.keyedvectors.Vocab at 0x7f04de382358>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f04de382390>,
#  'cherri': <gensim.models.keyedvectors.Vocab at 0x7f04de3823c8>,
#  'coffe': <gensim.models.keyedvectors.Vocab at 0x7f04de382400>,
#  'graphit': <gensim.models.keyedvectors.Vocab at 0x7f04de382438>,
#  'polish': <gensim.models.keyedvectors.Vocab at 0x7f04de382470>,
#  'sheen': <gensim.models.keyedvectors.Vocab at 0x7f04de3824a8>,
#  'load': <gensim.models.keyedvectors.Vocab at 0x7f04de3824e0>,
#  'chocol': <gensim.models.keyedvectors.Vocab at 0x7f04de382518>,
#  'espresso': <gensim.models.keyedvectors.Vocab at 0x7f04de382550>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7f04de382588>,
#  'formerli': <gensim.models.keyedvectors.Vocab at 0x7f04de3825c0>,
#  'bottl': <gensim.models.keyedvectors.Vocab at 0x7f04de3825f8>,
#  'youll': <gensim.models.keyedvectors.Vocab at 0x7f04de382630>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f04de382668>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x7f04de3826a0>,
#  'miner': <gensim.models.keyedvectors.Vocab at 0x7f04de3826d8>,
#  'underscor': <gensim.models.keyedvectors.Vocab at 0x7f04de382710>,
#  'chunki': <gensim.models.keyedvectors.Vocab at 0x7f04de382748>,
#  'accent': <gensim.models.keyedvectors.Vocab at 0x7f04de382780>,
#  'citru': <gensim.models.keyedvectors.Vocab at 0x7f04de3827b8>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7f04de3827f0>,
#  'midpal': <gensim.models.keyedvectors.Vocab at 0x7f04de382828>,
#  'concentr': <gensim.models.keyedvectors.Vocab at 0x7f04de382860>,
#  'cellar': <gensim.models.keyedvectors.Vocab at 0x7f04de382898>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f04de3828d0>,
#  'alreadi': <gensim.models.keyedvectors.Vocab at 0x7f04de382908>,
#  'quit': <gensim.models.keyedvectors.Vocab at 0x7f04de382978>,
#  '2030': <gensim.models.keyedvectors.Vocab at 0x7f04de3829b0>,
#  'produc': <gensim.models.keyedvectors.Vocab at 0x7f04de382048>,
#  'sourc': <gensim.models.keyedvectors.Vocab at 0x7f04de382080>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f04de3820b8>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7f04de3820f0>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f04de382128>,
#  'elev': <gensim.models.keyedvectors.Vocab at 0x7f04de382160>,
#  'contribut': <gensim.models.keyedvectors.Vocab at 0x7f04de382198>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x7f04de3821d0>,
#  'acid': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51f28>,
#  'crunchi': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51f60>,
#  'cranberri': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51f98>,
#  'pomegran': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51fd0>,
#  'surround': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51a90>,
#  'silki': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51ac8>,
#  'textur': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51b00>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51b38>,
#  'fleshi': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51b70>,
#  'delic': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51ba8>,
#  'lush': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51be0>,
#  'flavor': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51c18>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51c50>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51c88>,
#  'vine': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51cc0>,
#  'suppl': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51cf8>,
#  'wellbalanc': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51d30>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51d68>,
#  'mocha': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51da0>,
#  'vanilla': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51dd8>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51e10>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51e48>,
#  'superbl': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51e80>,
#  'integr': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51eb8>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51ef0>,
#  'earli': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51630>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51668>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f04cfc516a0>,
#  'destin': <gensim.models.keyedvectors.Vocab at 0x7f04cfc516d8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51710>,
#  'savori': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51748>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51780>,
#  'standout': <gensim.models.keyedvectors.Vocab at 0x7f04cfc517b8>,
#  'terrif': <gensim.models.keyedvectors.Vocab at 0x7f04cfc517f0>,
#  'lineup': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51828>,
#  '2015': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51860>,
#  'releas': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51898>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7f04cfc518d0>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51908>,
#  'burst': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51940>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51978>,
#  'tobacco': <gensim.models.keyedvectors.Vocab at 0x7f04cfc519b0>,
#  'scent': <gensim.models.keyedvectors.Vocab at 0x7f04cfc519e8>,
#  'continu': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51a20>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51a58>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51048>,
#  'thread': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51080>,
#  'ripe': <gensim.models.keyedvectors.Vocab at 0x7f04cfc510b8>,
#  'sophist': <gensim.models.keyedvectors.Vocab at 0x7f04cfc510f0>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51128>,
#  'tart': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51160>,
#  'seduct': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51198>,
#  'pleas': <gensim.models.keyedvectors.Vocab at 0x7f04cfc511d0>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51208>,
#  'strawberri': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51240>,
#  'blueberri': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51278>,
#  'plum': <gensim.models.keyedvectors.Vocab at 0x7f04cfc512b0>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7f04cfc512e8>,
#  'underli': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51320>,
#  'streak': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51358>,
#  'element': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51390>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f04cfc513c8>,
#  'proport': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51400>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51438>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51470>,
#  'anoth': <gensim.models.keyedvectors.Vocab at 0x7f04cfc514a8>,
#  'decad': <gensim.models.keyedvectors.Vocab at 0x7f04cfc514e0>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51518>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51550>,
#  '2006': <gensim.models.keyedvectors.Vocab at 0x7f04cfc51588>,
#  'lusciou': <gensim.models.keyedvectors.Vocab at 0x7f04cfc515c0>,
#  'chardonnay': <gensim.models.keyedvectors.Vocab at 0x7f04ce866da0>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f04ce866dd8>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7f04ce866e10>,
#  'butterscotch': <gensim.models.keyedvectors.Vocab at 0x7f04ce866e48>,
#  'seemingli': <gensim.models.keyedvectors.Vocab at 0x7f04ce866e80>,
#  'endless': <gensim.models.keyedvectors.Vocab at 0x7f04ce866eb8>,
#  'biodynam': <gensim.models.keyedvectors.Vocab at 0x7f04ce866ef0>,
#  'farm': <gensim.models.keyedvectors.Vocab at 0x7f04ce866f28>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f04ce866f60>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x7f04ce866f98>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x7f04ce866fd0>,
#  'lee': <gensim.models.keyedvectors.Vocab at 0x7f04ce866a20>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x7f04ce866a58>,
#  'blockbust': <gensim.models.keyedvectors.Vocab at 0x7f04ce866a90>,
#  'powerhous': <gensim.models.keyedvectors.Vocab at 0x7f04ce866ac8>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x7f04ce866b00>,
#  'pie': <gensim.models.keyedvectors.Vocab at 0x7f04ce866b38>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x7f04ce866b70>,
#  'smooth': <gensim.models.keyedvectors.Vocab at 0x7f04ce866ba8>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x7f04ce866be0>,
#  'cedar': <gensim.models.keyedvectors.Vocab at 0x7f04ce866c18>,
#  'peppercorn': <gensim.models.keyedvectors.Vocab at 0x7f04ce866c50>,
#  'pepperi': <gensim.models.keyedvectors.Vocab at 0x7f04ce866c88>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x7f04ce866cc0>,
#  'amidst': <gensim.models.keyedvectors.Vocab at 0x7f04ce866cf8>,
#  'finess': <gensim.models.keyedvectors.Vocab at 0x7f04ce866d30>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x7f04ce866d68>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x7f04ce866438>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f04ce866470>,
#  'mediumbodi': <gensim.models.keyedvectors.Vocab at 0x7f04ce8664a8>,
#  'beauti': <gensim.models.keyedvectors.Vocab at 0x7f04ce8664e0>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x7f04ce866518>,
#  'blossom': <gensim.models.keyedvectors.Vocab at 0x7f04ce866550>,
#  'tangi': <gensim.models.keyedvectors.Vocab at 0x7f04ce866588>,
#  'crisp': <gensim.models.keyedvectors.Vocab at 0x7f04ce8665c0>,
#  'bake': <gensim.models.keyedvectors.Vocab at 0x7f04ce8665f8>,
#  'readi': <gensim.models.keyedvectors.Vocab at 0x7f04ce866630>,
#  'tabl': <gensim.models.keyedvectors.Vocab at 0x7f04ce866668>,
#  'ambiti': <gensim.models.keyedvectors.Vocab at 0x7f04ce8666a0>,
#  'wineri': <gensim.models.keyedvectors.Vocab at 0x7f04ce8666d8>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x7f04ce866710>,
#  'clone': <gensim.models.keyedvectors.Vocab at 0x7f04ce866748>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7f04ce866780>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f04ce8667b8>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x7f04ce8667f0>,
#  'marzipan': <gensim.models.keyedvectors.Vocab at 0x7f04ce866828>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x7f04ce866860>,
#  'peach': <gensim.models.keyedvectors.Vocab at 0x7f04ce866898>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7f04ce8668d0>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x7f04ce866908>,
#  'sizzl': <gensim.models.keyedvectors.Vocab at 0x7f04ce866940>,
#  'salti': <gensim.models.keyedvectors.Vocab at 0x7f04ce866978>,
#  'lemoni': <gensim.models.keyedvectors.Vocab at 0x7f04ce8669e8>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f04ce866048>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x7f04ce866080>,
#  'butter': <gensim.models.keyedvectors.Vocab at 0x7f04ce8660b8>,
#  'luxuri': <gensim.models.keyedvectors.Vocab at 0x7f04ce8660f0>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x7f04ce866128>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f04ce866160>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x7f04ce866198>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x7f04ce8661d0>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x7f04ce866208>,
#  'sage': <gensim.models.keyedvectors.Vocab at 0x7f04ce866240>,
#  'eucalyptu': <gensim.models.keyedvectors.Vocab at 0x7f04ce866278>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f04ce8662b0>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7f04ce8662e8>,
#  'aciddriven': <gensim.models.keyedvectors.Vocab at 0x7f04ce866320>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x7f04ce866358>,
#  'junip': <gensim.models.keyedvectors.Vocab at 0x7f04ce866390>,
#  'pine': <gensim.models.keyedvectors.Vocab at 0x7f04ce8663c8>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x7f04ce866400>,
#  'leaf': <gensim.models.keyedvectors.Vocab at 0x7f04d10841d0>,
#  'sensat': <gensim.models.keyedvectors.Vocab at 0x7f04d1084208>,
#  'yield': <gensim.models.keyedvectors.Vocab at 0x7f04d1084240>,
#  'intens': <gensim.models.keyedvectors.Vocab at 0x7f04d1084278>,
#  'potenti': <gensim.models.keyedvectors.Vocab at 0x7f04d10842b0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f04d10842e8>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f04d1084320>,
#  '2025': <gensim.models.keyedvectors.Vocab at 0x7f04d1084390>,
#  'hickori': <gensim.models.keyedvectors.Vocab at 0x7f04d10843c8>,
#  'smoke': <gensim.models.keyedvectors.Vocab at 0x7f04d1084400>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f04d1084550>,
#  'lime': <gensim.models.keyedvectors.Vocab at 0x7f04d1084c18>,
#  'zest': <gensim.models.keyedvectors.Vocab at 0x7f04d1084978>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7f04d10849b0>,
#  'sinc': <gensim.models.keyedvectors.Vocab at 0x7f04d10849e8>,
#  '2003': <gensim.models.keyedvectors.Vocab at 0x7f04d1084a20>,
#  'showcas': <gensim.models.keyedvectors.Vocab at 0x7f04d1084a58>,
#  'pretti': <gensim.models.keyedvectors.Vocab at 0x7f04d1084438>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x7f04d1084470>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f04d10844a8>,
#  'grape': <gensim.models.keyedvectors.Vocab at 0x7f04d10844e0>,
#  'jelli': <gensim.models.keyedvectors.Vocab at 0x7f04d1084518>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x7f04d1084588>,
#  'petal': <gensim.models.keyedvectors.Vocab at 0x7f04d10845c0>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f04d10845f8>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x7f04d1084630>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x7f04d1084668>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f04d10846a0>,
#  'gener': <gensim.models.keyedvectors.Vocab at 0x7f04d10846d8>,
#  'captur': <gensim.models.keyedvectors.Vocab at 0x7f04d1084710>,
#  'essenc': <gensim.models.keyedvectors.Vocab at 0x7f04d1084748>,
#  'raspberri': <gensim.models.keyedvectors.Vocab at 0x7f04d1084048>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x7f04d1084080>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f04d10840b8>,
#  'vein': <gensim.models.keyedvectors.Vocab at 0x7f04d10840f0>,
#  'broaden': <gensim.models.keyedvectors.Vocab at 0x7f04d1084128>,
#  'penetr': <gensim.models.keyedvectors.Vocab at 0x7f04d1084198>,
#  'highlight': <gensim.models.keyedvectors.Vocab at 0x7f04d1084358>,
#  'cinnamon': <gensim.models.keyedvectors.Vocab at 0x7f04d1084a90>,
#  '2020': <gensim.models.keyedvectors.Vocab at 0x7f04d1084ac8>,
#  'decant': <gensim.models.keyedvectors.Vocab at 0x7f04d1084b00>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f04d1084b38>,
#  'express': <gensim.models.keyedvectors.Vocab at 0x7f04d1084b70>,
#  'rhubarb': <gensim.models.keyedvectors.Vocab at 0x7f04d1084ba8>,
#  'anis': <gensim.models.keyedvectors.Vocab at 0x7f04d1084be0>,
#  'crush': <gensim.models.keyedvectors.Vocab at 0x7f04d1084c50>,
#  'slate': <gensim.models.keyedvectors.Vocab at 0x7f04d1084c88>,
#  'famili': <gensim.models.keyedvectors.Vocab at 0x7f04d1084cc0>,
#  'abound': <gensim.models.keyedvectors.Vocab at 0x7f04d1084cf8>}

# %% [markdown]
# Play around with words:

# %%
w1 = "oak"
w2v_model.wv.most_similar(positive=w1, topn=5)
# Out:
# [('vanillin', 0.5975340008735657),
#  ('charri', 0.5841033458709717),
#  ('vanillasc', 0.5780559182167053),
#  ('oaki', 0.5621522665023804),
#  ('applic', 0.5467074513435364)]

# %%
w1 = "melon"
w2v_model.wv.most_similar(positive=w1, topn=10)
# Out:
# [('honeydew', 0.7312850952148438),
#  ('meloni', 0.714074969291687),
#  ('nectarin', 0.7120921611785889),
#  ('cantaloup', 0.7000508308410645),
#  ('papaya', 0.691330075263977),
#  ('lyche', 0.6887291669845581),
#  ('tropicalfruit', 0.6728799939155579),
#  ('appl', 0.6706262230873108),
#  ('banana', 0.6650311946868896),
#  ('whitefruit', 0.662381649017334)]

# %%
w2v_model.wv.doesnt_match(["milk","espresso","oak"])
# Out:
# /opt/conda/lib/python3.6/site-packages/gensim/models/keyedvectors.py:876: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'oak'

# %%
#ref: https://www.kaggle.com/liananapalkova/simply-about-word2vec

# %% [markdown]
# ## KMean Clustering

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
kmeans = MiniBatchKMeans(n_clusters = 5, n_init = 5)
kmeans.fit(matrix)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=5, n_init=5, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

# %%
for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :4]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d titles:" % i, end='')
    for title in frame.ix[i]['title'].values.tolist():
        print(' %s,' % title, end='')
    print() #add whitespace
    print() #add whitespace

# %%
clusters = df_word.groupby(['cluster', 'variety']).size()
fig2, ax2 = plt.subplots(figsize = (20, 20))
sns.heatmap(clusters.unstack(level = 'variety'), ax = ax2, cmap = 'Reds',annot = True)

ax2.set_xlabel('variety', fontdict = {'weight': 'bold', 'size': 24})
ax2.set_ylabel('cluster', fontdict = {'weight': 'bold', 'size': 24})
for label in ax2.get_xticklabels():
    label.set_size(16)
    label.set_weight("bold")
for label in ax2.get_yticklabels():
    label.set_size(16)
    label.set_weight("bold")
